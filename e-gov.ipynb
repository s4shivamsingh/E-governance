# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data="rural_up.csv"

# %%
df=pd.read_csv(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 39 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Name (Optional)                                                                          0 non-null      float64
#  1   Gender                                                                                   599 non-null    object
#  2   Address                                                                                  0 non-null      float64
#  3   Profession                                                                               599 non-null    object
#  4   Education                                                                                599 non-null    object
# ...

# %%
df.shape
# Out:
# (599, 39)

# %%
df.head()
# Out:
#    Name (Optional) Gender  Address      Profession       Education  \
# 0              NaN      m      NaN  Public Servent        Graduate
# 1              NaN      m      NaN  Public Servent        Graduate
# 2              NaN      f      NaN  Public Servent  Above Graduate
# 3              NaN      m      NaN  Public Servent        Graduate
# 4              NaN      m      NaN  Public Servent             SLC
#
#   Heard e-gov Know e-gov Target of Nepal Org sector of local level  \
# 0         yes                         no            administrative
# 1         yes                         no            administrative
# 2         yes                        yes            administrative
# 3         yes                         no            administrative
# 4          no                         no            administrative
#
#   Gender Sector Age Group  ... Political (EF 2) Economical (EF 3)  \
# 0             m  26 to 35  ...                1                 3
# ...

# %%
df.isnull().sum()
# Out:
# Name (Optional)                                                                            599
# Gender                                                                                       0
# Address                                                                                    599
# Profession                                                                                   0
# Education                                                                                    0
# Heard e-gov                                                                                  0
# Know e-gov Target of Nepal                                                                   0
# Org sector of local level                                                                    0
# Gender Sector                                                                                0
# Age Group                                                                                    0
# ...

# %%
df["use of e-goverance reduces overall cost of organization (i)"].unique()
df["use of e-goverance improves productivity and increase capacity of government (ii)"].unique()
df["use of e-goverance improve collaboration among different departments (iii)"].unique()
df["use of e-goverance improves accounttability, transparancy and anty-corruption (iv)"].unique()
df["use of e-goverance have information threat that is identity theft, unstable network (v)"].unique()
df["use of e-goverance will lead to misuse of government services (vi)"].unique()
df["e-governance needs higher level of knowledge among employees (vii)"].unique()
df["It need huge inverstment in participating in e-governance (viii)"].unique()
df["Do you think that there will a caltural barrier while  implementing e-governance (ix)"].unique()
df["Political support id important for e-governance implementation (x)"].unique()
df["ICT infrastructure plays important role in e-governance (xi)"].unique()
df["Leadership role is important for motivation and support to implement e-governance (xii)"].unique()
df["It needs more technical skills to implement e-governance (xiii)"].unique()
df["It Needs Lot of Training and setup cost (xiv)"].unique()
# Out:
# array([ 2.,  3.,  1.,  4., nan,  5.])

# %%
avg1=df["use of e-goverance reduces overall cost of organization (i)"].mean()
avg2=df["use of e-goverance improves productivity and increase capacity of government (ii)"].mean()
avg3=df["use of e-goverance improve collaboration among different departments (iii)"].mean()
avg4=df["use of e-goverance improves accounttability, transparancy and anty-corruption (iv)"].mean()
avg5=df["use of e-goverance have information threat that is identity theft, unstable network (v)"].mean()
avg6=df["use of e-goverance will lead to misuse of government services (vi)"].mean()
avg7=df["e-governance needs higher level of knowledge among employees (vii)"].mean()
avg8=df["It need huge inverstment in participating in e-governance (viii)"].mean()
avg9=df["Do you think that there will a caltural barrier while  implementing e-governance (ix)"].mean()
avg10=df["Political support id important for e-governance implementation (x)"].mean()
avg11=df["ICT infrastructure plays important role in e-governance (xi)"].mean()
avg12=df["Leadership role is important for motivation and support to implement e-governance (xii)"].mean()
avg13=df["It needs more technical skills to implement e-governance (xiii)"].mean()
avg14=df["It Needs Lot of Training and setup cost (xiv)"].mean()


df["use of e-goverance reduces overall cost of organization (i)"].replace(np.nan,avg1,inplace=True)
df["use of e-goverance improves productivity and increase capacity of government (ii)"].replace(np.nan,avg2,inplace=True)
df["use of e-goverance improve collaboration among different departments (iii)"].replace(np.nan,avg3,inplace=True)
df["use of e-goverance improves accounttability, transparancy and anty-corruption (iv)"].replace(np.nan,avg4,inplace=True)
df["use of e-goverance have information threat that is identity theft, unstable network (v)"].replace(np.nan,avg5,inplace=True)
df["use of e-goverance will lead to misuse of government services (vi)"].replace(np.nan,avg6,inplace=True)
df["e-governance needs higher level of knowledge among employees (vii)"].replace(np.nan,avg7,inplace=True)
df["It need huge inverstment in participating in e-governance (viii)"].replace(np.nan,avg8,inplace=True)
df["Do you think that there will a caltural barrier while  implementing e-governance (ix)"].replace(np.nan,avg9,inplace=True)
df["Political support id important for e-governance implementation (x)"].replace(np.nan,avg10,inplace=True)
df["ICT infrastructure plays important role in e-governance (xi)"].replace(np.nan,avg11,inplace=True)
df["Leadership role is important for motivation and support to implement e-governance (xii)"].replace(np.nan,avg12,inplace=True)
df["It needs more technical skills to implement e-governance (xiii)"].replace(np.nan,avg13,inplace=True)
df["It Needs Lot of Training and setup cost (xiv)"].replace(np.nan,avg14,inplace=True)

# %%
df["use of e-goverance reduces overall cost of organization (i)"]=df["use of e-goverance reduces overall cost of organization (i)"].astype(int)
df["use of e-goverance improves productivity and increase capacity of government (ii)"]=df["use of e-goverance improves productivity and increase capacity of government (ii)"].astype(int)
df["use of e-goverance improve collaboration among different departments (iii)"]=df["use of e-goverance improve collaboration among different departments (iii)"].astype(int)
df["use of e-goverance improves accounttability, transparancy and anty-corruption (iv)"]=df["use of e-goverance improves accounttability, transparancy and anty-corruption (iv)"].astype(int)
df["use of e-goverance have information threat that is identity theft, unstable network (v)"]=df["use of e-goverance have information threat that is identity theft, unstable network (v)"].astype(int)
df["use of e-goverance will lead to misuse of government services (vi)"]=df["use of e-goverance will lead to misuse of government services (vi)"].astype(int)
df["e-governance needs higher level of knowledge among employees (vii)"]=df["e-governance needs higher level of knowledge among employees (vii)"].astype(int)
df["It need huge inverstment in participating in e-governance (viii)"]=df["It need huge inverstment in participating in e-governance (viii)"].astype(int)
df["Do you think that there will a caltural barrier while  implementing e-governance (ix)"]=df["Do you think that there will a caltural barrier while  implementing e-governance (ix)"].astype(int)
df["Political support id important for e-governance implementation (x)"]=df["Political support id important for e-governance implementation (x)"].astype(int)
df["ICT infrastructure plays important role in e-governance (xi)"]=df["ICT infrastructure plays important role in e-governance (xi)"].astype(int)
df["Leadership role is important for motivation and support to implement e-governance (xii)"]=df["Leadership role is important for motivation and support to implement e-governance (xii)"].astype(int)
df["It needs more technical skills to implement e-governance (xiii)"]=df["It needs more technical skills to implement e-governance (xiii)"].astype(int)
df["It Needs Lot of Training and setup cost (xiv)"]=df["It Needs Lot of Training and setup cost (xiv)"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 39 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Name (Optional)                                                                          0 non-null      float64
#  1   Gender                                                                                   599 non-null    object
#  2   Address                                                                                  0 non-null      float64
#  3   Profession                                                                               599 non-null    object
#  4   Education                                                                                599 non-null    object
# ...

# %%
df.describe()
# Out:
#        Name (Optional)  Address  \
# count              0.0      0.0
# mean               NaN      NaN
# std                NaN      NaN
# min                NaN      NaN
# 25%                NaN      NaN
# 50%                NaN      NaN
# 75%                NaN      NaN
# max                NaN      NaN
#
#        use of e-goverance reduces overall cost of organization (i)  \
# count                                         599.000000
# mean                                            3.687813
# std                                             1.126320
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        use of e-goverance improves productivity and increase capacity of government (ii)  \
# ...

# %%
df.isnull().sum()
# Out:
# Name (Optional)                                                                            599
# Gender                                                                                       0
# Address                                                                                    599
# Profession                                                                                   0
# Education                                                                                    0
# Heard e-gov                                                                                  0
# Know e-gov Target of Nepal                                                                   0
# Org sector of local level                                                                    0
# Gender Sector                                                                                0
# Age Group                                                                                    0
# ...

# %%
df.drop(['Name (Optional)','Address','Gender Sector','Heighest Qualification'],axis=1,inplace=True)
df.head()
# Out:
#   Gender      Profession       Education Heard e-gov  \
# 0      m  Public Servent        Graduate         yes
# 1      m  Public Servent        Graduate         yes
# 2      f  Public Servent  Above Graduate         yes
# 3      m  Public Servent        Graduate         yes
# 4      m  Public Servent             SLC          no
#
#   Know e-gov Target of Nepal Org sector of local level Age Group  \
# 0                         no            administrative  26 to 35
# 1                         no            administrative  36 to 45
# 2                        yes            administrative  26 to 35
# 3                         no            administrative  36 to 45
# 4                         no            administrative  26 to 35
#
#   No. of employee in Organization your org participating in e-gov (years)  \
# 0                        11 to 50                                  1 to 2
# 1                        11 to 50                                 2 to 5
# ...

# %%
df.shape
# Out:
# (599, 35)

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g = sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
plt.show()

# %%
df.corr()
# Out:
#                                                     use of e-goverance reduces overall cost of organization (i)  \
# use of e-goverance reduces overall cost of orga...                                           1.000000
# use of e-goverance improves productivity and in...                                           0.438050
# use of e-goverance improve collaboration among ...                                           0.349054
# use of e-goverance improves accounttability, tr...                                           0.135781
# use of e-goverance have information threat that...                                           0.199283
# use of e-goverance will lead to misuse of gover...                                          -0.150707
# e-governance needs higher level of knowledge am...                                           0.028036
# It need huge inverstment in participating in e-...                                          -0.100829
# ...

# %%
sns.countplot(x="Profession",hue='Gender',data=df,palette = 'magma')
plt.legend(loc='upper right')
plt.show()

# %%
fig=plt.figure(figsize=(10,5))
sns.countplot(x="Education",hue='Gender',data=df, saturation=1,palette = 'magma')
plt.legend(loc='upper right')
plt.show()

# %%
fig=plt.figure(figsize=(10,5))
sns.countplot(x="No. of employee in Organization",hue="Org sector of local level",data=df ,bottom=0,palette = 'magma')
plt.legend(loc='upper right')
plt.show()

# %%
df['No. of employee in Organization'].unique()
# Out:
# array(['11 to 50', '51 TO 100', '51 to 100', '101 to 500'], dtype=object)

# %%
fig=plt.figure(figsize=(7,7))
plt.bar(x=df['No. of employee in Organization'],height=df['Org sector of local level'],bottom=-1,color='purple')
plt.xlabel('No. of employee in Organization')
plt.ylabel('Org sector of local level')
plt.title("ratio of male and female in different sector")
plt.xticks(rotation=60)
plt.show()

# %%
#df = pd.DataFrame(zip(x*3, ["y"]*3+["z"]*3+["k"]*3, y+z+k), columns=["No. of employee in Organization", "Gender", "Org sector of local level"])
plt.figure(figsize=(10, 6))
sns.countplot(x="Org sector of local level", hue="Gender", data=df,palette = 'magma')
plt.legend(loc='upper right')
plt.show()

# %%
sns.countplot(x="Heard e-gov",hue='Gender',data=df,palette = 'magma')
plt.show()

# %%
sns.countplot(x="Heard e-gov",hue='Age Group',data=df,palette = 'magma')
plt.show()

# %%
sns.countplot(x="Heard e-gov",hue='Org sector of local level',data=df,palette = 'magma')
plt.show()

# %%
sns.countplot(x="Heard e-gov",hue='Education',data=df,palette = 'magma')
plt.show()

# %%
sns.countplot(x="your org participating in e-gov (years)",hue='Org sector of local level',data=df,palette = 'magma')
plt.show()

# %%
sns.countplot(x="does your organization have strategy on e-gov",hue='Org sector of local level',data=df,palette = 'magma')
plt.legend(loc='upper right')
plt.show()

# %%
x=df.iloc[:,24:30]
x.hist(figsize=(20,10))
plt.show()

# %%
y=df.iloc[:,-5:]
y.hist(figsize=(20,10))
plt.show()

# %%
plt.figure(figsize=(25,30))

plt.subplot(7,2,1)
sns.countplot(x='use of e-goverance reduces overall cost of organization (i)',data=df)

plt.subplot(7,2,2)
sns.countplot(x='use of e-goverance improves productivity and increase capacity of government (ii)',data=df)

plt.subplot(7,2,3)
sns.countplot(x='use of e-goverance improve collaboration among different departments (iii)',data=df)

plt.subplot(7,2,4)
sns.countplot(x='use of e-goverance improves accounttability, transparancy and anty-corruption (iv)',data=df)

plt.subplot(7,2,5)
sns.countplot(x='use of e-goverance have information threat that is identity theft, unstable network (v)',data=df)

plt.subplot(7,2,6)
sns.countplot(x='use of e-goverance will lead to misuse of government services (vi)',data=df)

plt.subplot(7,2,7)
sns.countplot(x='e-governance needs higher level of knowledge among employees (vii)',data=df)

plt.subplot(7,2,8)
sns.countplot(x='It need huge inverstment in participating in e-governance (viii)',data=df)

plt.subplot(7,2,9)
sns.countplot(x='Do you think that there will a caltural barrier while  implementing e-governance (ix)',data=df)

plt.subplot(7,2,10)
sns.countplot(x='Political support id important for e-governance implementation (x)',data=df)

plt.subplot(7,2,11)
sns.countplot(x='ICT infrastructure plays important role in e-governance (xi)',data=df)

plt.subplot(7,2,12)
sns.countplot(x='Leadership role is important for motivation and support to implement e-governance (xii)',data=df)

plt.subplot(7,2,13)
sns.countplot(x='It needs more technical skills to implement e-governance (xiii)',data=df)

plt.subplot(7,2,14)
sns.countplot(x='It Needs Lot of Training and setup cost (xiv)',data=df)

plt.show()
